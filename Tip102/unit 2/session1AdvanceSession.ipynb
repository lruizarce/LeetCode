# %%
def total_treasures(treasure_map):
    pass


treasure_map1 = {"Cove": 3, "Beach": 7, "Forest": 5}

treasure_map2 = {"Shipwreck": 10, "Cave": 20, "Lagoon": 15, "Island Peak": 5}

print(total_treasures(treasure_map1))
print(total_treasures(treasure_map2))
# Out:
# None
# None

# %%
def can_trust_message(message):
    pass


message1 = "sphinx of black quartz judge my vow"
message2 = "trust me"

print(can_trust_message(message1))
print(can_trust_message(message2))
# Out:
# None
# None

# %%
def find_duplicate_chests(chests):
    pass


chests1 = [4, 3, 2, 7, 8, 2, 3, 1]
chests2 = [1, 1, 2]
chests3 = [1]

print(find_duplicate_chests(chests1))
print(find_duplicate_chests(chests2))
print(find_duplicate_chests(chests3))

# %%
def is_balanced(code):
    pass


code1 = "arghh"
code2 = "haha"

print(is_balanced(code1))
print(is_balanced(code2))

# %%
def find_duplicate_chests(chests):
    freqCount = {}
    for i in chests:
        if i not in freqCount:
            freqCount[i] = 1
        else:
            freqCount[i] += 1

    res = []
    for k, v in freqCount.items():
        if v == 2:
            res.append(k)
    return res


chests1 = [4, 3, 2, 7, 8, 2, 3, 1]
chests2 = [1, 1, 2]
chests3 = [1]

print(find_duplicate_chests(chests1))
print(find_duplicate_chests(chests2))
print(find_duplicate_chests(chests3))
# Out:
# [3, 2]
# [1]
# []

# %%
from collections import Counter


def is_balanced(code):
    freqCount = Counter(code)

    freqVal = list(freqCount.values())

    freqDist = Counter(freqVal)

    if len(freqDist) == 1 or len(freqDist) > 2:
        return False

    freqKeys = sorted(freqDist.keys())

    if freqKeys[0] == 1 and freqDist[freqKeys[0]] == 1:
        return True

    if freqKeys[1] == freqKeys[0] + 1 and freqDist[freqKeys[1]] == 1:
        return True
    return False


code1 = "arghh"
code2 = "haha"

print(is_balanced(code1))
print(is_balanced(code2))
# Out:
# True
# False

# %%
def find_treasure_indices(gold_amounts, target):
    seen = {}
    for i in range(len(gold_amounts)):
        remainder = target - gold_amounts[i]
        if remainder in seen:
            return [seen[remainder], i]
        else:
            seen[gold_amounts[i]] = i


gold_amounts1 = [2, 7, 11, 15]
target1 = 9

gold_amounts2 = [3, 2, 4]
target2 = 6

gold_amounts3 = [3, 3]
target3 = 6

print(find_treasure_indices(gold_amounts1, target1))
print(find_treasure_indices(gold_amounts2, target2))
print(find_treasure_indices(gold_amounts3, target3))
# Out:
# [0, 1]
# [1, 2]
# [0, 1]
